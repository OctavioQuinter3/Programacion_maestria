# %% [markdown]
# <a href="https://colab.research.google.com/github/OctavioQuinter3/Programacion_maestria/blob/main/Practica10_266226.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Datos de alumno
#
# Estudiante: Octavio Quintero Flores
#
# Matricula: 266226
#
# Maestría en Inteligencia Artificial y Analítica de Datos

# %% [markdown]
# # Instrucciones de la actividad
#
# Objetivo
# Utilizar GridSpec para organizar subplots de diferentes tamaños en un análisis de ventas.
#
# Instrucciones:
# Genera un DataFrame de ventas con Mes, Ventas, y Gastos. Utiliza randint para generar números aleatorios enteros. Para ventas los valores deben estar entre 2000 y 5000. Para gastos, los valores debn estar entre 1000 y 4000.
# Usa GridSpec para organizar los subplots de la siguiente manera:
# Primer gráfico (barra, ocupando dos columnas)
# Segundo gráfico (línea, una columna)
# Tercer gráfico (dispersión, dos filas).
# Agrega títulos y ajusta espacios.

# %% [markdown]
# #Inicio de actividad

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec

# %%
meses = ["Ene", "Feb", "Mar", "Abr", "May", "Jun",
         "Jul", "Ago", "Sep", "Oct", "Nov", "Dic"]

data = pd.DataFrame({
    "Mes": meses,
    "Ventas": np.random.randint(2000, 5000, 12),
    "Gastos": np.random.randint(1000, 4000, 12)
})

# %%
fig = plt.figure(figsize=(18,8))
gs = GridSpec(2,2)

# %%
ax1 = fig.add_subplot(gs[0,:])
ax1.bar(data["Mes"], data["Ventas"])
ax1.set_title("Ventas Mensuales")
# Out:
# Text(0.5, 1.0, 'Ventas Mensuales')

# %%
ax2 = fig.add_subplot(gs[1,0])
ax2.plot(data["Mes"], data["Gastos"])
ax2.set_title("Gastos Mensuales")
# Out:
# Text(0.5, 1.0, 'Gastos Mensuales')

# %%
ax3 = fig.add_subplot(gs[1,1])
ax3.scatter(data["Ventas"], data["Gastos"])
ax3.set_title("Ventas vs Gastos")
# Out:
# Text(0.5, 1.0, 'Ventas vs Gastos')

# %%
plt.tight_layout()
display(fig)
