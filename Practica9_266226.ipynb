# %% [markdown]
# <a href="https://colab.research.google.com/github/OctavioQuinter3/Programacion_maestria/blob/main/Practica9_266226.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Datos de alumno
#
# Estudiante: Octavio Quintero Flores
#
# Matricula: 266226
#
# Maestría en Inteligencia Artificial y Analítica de Datos

# %% [markdown]
# # Instrucciones de la actividad
#
# Objetivo
# Utilizar plt.subplots() para visualizar diferentes distribuciones generadas con NumPy y almacenadas en un DataFrame.
#
# Instrucciones:
# Genera un DataFrame con Pandas que contenga 1000 valores en cuatro columnas (Normal, Uniforme, Exponencial, Poisson).
# Crea una figura con plt.subplots(2, 2) para organizar los histogramas en una cuadrícula de 2x2.
# Grafica cada distribución en un subplot usando ax[i, j].hist().
# Agrega títulos a cada subplot y ajusta la disposición con tight_layout().

# %% [markdown]
# #Inicio de actividad

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
datos = pd.DataFrame({
    "Normal": np.random.normal(size=1000),
    "Uniforme": np.random.uniform(size=1000),
    "Exponencial": np.random.exponential(size=1000),
    "Poisson": np.random.poisson(size=1000)
})

datos.head()
# Out:
#      Normal  Uniforme  Exponencial  Poisson
# 0  0.051330  0.926354     0.107397        1
# 1  0.653824  0.553746     1.791099        1
# 2 -0.591212  0.487998     5.484466        2
# 3 -1.111885  0.223513     0.532833        1
# 4  1.207901  0.269770     0.313905        3

# %%
fig, ax = plt.subplots(2, 2, figsize=(10, 10))
ax[0, 0].hist(datos["Normal"], bins=30)
ax[0, 0].set_title("Normal")

ax[0, 1].hist(datos["Uniforme"], bins=30)
ax[0, 1].set_title("Uniforme")

ax[1, 0].hist(datos["Exponencial"], bins=30)
ax[1, 0].set_title("Exponencial")

ax[1, 1].hist(datos["Poisson"], bins=30)
ax[1, 1].set_title("Poisson")
# Out:
# Text(0.5, 1.0, 'Poisson')
